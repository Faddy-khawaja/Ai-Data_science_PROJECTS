# %% [markdown]
# 1, Write a Python program to manage and analyze student marks.
# Requirements:
# • Input the total number of students.
# • For each student, take their name and marks (out of 100).
# • Store names and marks in lists.
# • After taking all inputs: display all students with their marks, find and display highest marks, lowest
# marks, and average marks.
# • Assign grade using if-else conditions as follows: Marks ≥ 80 → Grade A, Marks 60–79 → Grade B,
# Marks 40–59 → Grade C, Marks < 40 → Grade F.
# Sample Output:
# Enter number of students: 3 Enter name of student 1: Ali Enter marks of Ali: 85 Enter name of student 2:
# Sara Enter marks of Sara: 72 Enter name of student 3: Hamza Enter marks of Hamza: 39 --- Student
# Results --- Ali - 85 - Grade A Sara - 72 - Grade B Hamza - 39 - Grade F Highest Marks: 85 Lowest
# Marks: 39 Average Marks: 65.3

# %%
def main():

    num_students = int(input("Enter number of students: "))


    names = []
    marks = []

    for i in range(num_students):
        name = input(f"Enter name of student {i+1}: ")
        mark = int(input(f"Enter marks of {name}: "))

        names.append(name)
        marks.append(mark)

    print("\n--- Student Results ---")
    for i in range(num_students):

        if marks[i] >= 80:
            grade = "A"
        elif marks[i] >= 60:
            grade = "B"
        elif marks[i] >= 40:
            grade = "C"
        else:
            grade = "F"

        print(f"{names[i]} - {marks[i]} - Grade {grade}")

    highest_marks = max(marks)
    lowest_marks = min(marks)
    average_marks = sum(marks) / num_students

    print(f"\nHighest Marks: {highest_marks}")
    print(f"Lowest Marks: {lowest_marks}")
    print(f"Average Marks: {average_marks:.1f}")

# %% [markdown]
# Question 2: Grocery Billing System (Marks: 35)

# %%
def calculate_grocery_bill():

    items = {
        "apple": 200,
        "banana": 60,
        "rice": 150,
        "milk": 120,
        "bread": 100
    }

    print(" Available Items:")
    for item, price in items.items():
        print(f"  {item.title()} - ₹{price}")

    total = 0
    bill_items = []

    while True:
        print(f"\nCurrent total: ₹{total}")
        item_name = input("\nEnter item name (or 'done' to finish): ").strip().lower()

        if item_name == 'done':
            break

        if item_name not in items:
            print("Invalid item name. Please try again.")


        quantity = int(input("Enter quantity: "))

        price = items[item_name]
        subtotal = price * quantity
        total += subtotal
        bill_items.append(f"{item_name.title()} ({quantity}) = ₹{subtotal}")


    print("\n" + "="*30)
    print(" BILL SUMMARY")
    print("="*30)

    for item in bill_items:
        print(item)

    print("-"*30)
    print(f"Total: ₹{total}")


    if total > 1000:
        discount = total * 0.10
        final_total = total - discount
        print(f"Discount (10%): {discount}")
        print(f"Final Amount: {final_total}")
    else:
        print("No discount applied")
        print(f"Final Amount: {total}")

calculate_grocery_bill()
# Out:
#  Available Items:
#   Apple - ₹200
#   Banana - ₹60
#   Rice - ₹150
#   Milk - ₹120
#   Bread - ₹100
#
# Current total: ₹0

# %% [markdown]
# Question 3: Number Guessing Game (Marks: 30)

# %%
secret = 7

for chance in range(5):
    guess = int(input("Guess the number (between 1-10): "))

    if guess == secret:
        print("Correct Guess!")
        break
    elif guess < secret:
        print("Too Low!")
    else:
        print("Too High!")
else:
    print(f"Game Over! The number was {secret}.")
# Out:
# Guess the number (between 1-10):     8
# Too High!
# Guess the number (between 1-10):   5
# Too Low!
# Guess the number (between 1-10): 7
# Correct Guess!
